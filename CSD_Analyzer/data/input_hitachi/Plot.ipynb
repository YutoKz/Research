# %%
#import pyarbtools
import pyvisa as visa
from zhinst.toolkit import Session#https://docs.zhinst.com/zhinst-toolkit/en/latest/
from zhinst.toolkit import Sequence
import matplotlib.pyplot as plt
import time
import numpy as np
import datetime 
import glob
import pandas as pd

# %%
filename_list = glob.glob('./*npy')
filename_list
# Out:
# ['.\\2023-03-22_15_08_57.485748.npy']

# %%
filename1 =filename_list[0]
print(filename1)
# filename1='2022-12-27_21_12_01.283930.npy'
B = np.load(filename1)
# Out:
# .\2023-03-22_15_08_57.485748.npy

# %%
plt.figure(figsize=(24,18))
plt.rcParams["font.size"] = 16
plt.pcolormesh(B[0],B[1],B[2]/1000,shading='nearest',cmap='hot')
# plt.pcolormesh(np.array(result_ave)/Gain,shading='nearest',cmap='hot')
plt.title(filename1,fontsize=15)
plt.colorbar()
plt.clim([0, 10**-9.5])
plt.xlabel("SGS(V)",fontsize=20)
plt.ylabel("SG3(V)",fontsize=20)
# plt.xlim([1.5,1.8])
# plt.ylim([1,2.5])
#################################################################
# Out:
# Text(0, 0.5, 'SG3(V)')
